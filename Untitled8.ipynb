# %% [markdown]
# <a href="https://colab.research.google.com/github/heenamandalgithub/Python-Practice-Program/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("spotify.csv")

# %%
df.head()
# Out:
#          Date  Shape of You  ...  HUMBLE.  Unforgettable
# 0  2017-01-06      12287078  ...      NaN            NaN
# 1  2017-01-07      13190270  ...      NaN            NaN
# 2  2017-01-08      13099919  ...      NaN            NaN
# 3  2017-01-09      14506351  ...      NaN            NaN
# 4  2017-01-10      14275628  ...      NaN            NaN
#
# [5 rows x 6 columns]

# %%
df.tail()
# Out:
#            Date  Shape of You  ...    HUMBLE.  Unforgettable
# 361  2018-01-05       4492978  ...  2685857.0      2869783.0
# 362  2018-01-06       4416476  ...  2559044.0      2743748.0
# 363  2018-01-07       4009104  ...  2350985.0      2441045.0
# 364  2018-01-08       4135505  ...  2523265.0      2622693.0
# 365  2018-01-09       4168506  ...  2727678.0      2627334.0
#
# [5 rows x 6 columns]

# %%
df.describe()
# Out:
#        Shape of You     Despacito  ...       HUMBLE.  Unforgettable
# count  3.660000e+02  3.590000e+02  ...  2.820000e+02   2.750000e+02
# mean   8.180297e+06  9.165803e+06  ...  4.649801e+06   4.687821e+06
# std    4.233482e+06  5.990592e+06  ...  2.503079e+06   1.751676e+06
# min    3.497682e+06  2.751780e+05  ...  1.638493e+06   3.088380e+05
# 25%    4.447564e+06  4.189972e+06  ...  2.780524e+06   3.258119e+06
# 50%    6.631300e+06  6.889959e+06  ...  3.629818e+06   4.772899e+06
# 75%    1.192114e+07  1.445198e+07  ...  6.374150e+06   6.314862e+06
# max    1.976474e+07  2.321818e+07  ...  1.314496e+07   7.483165e+06
#
# [8 rows x 5 columns]

# %%
df.isnull()
# Out:
#       Date  Shape of You  ...  HUMBLE.  Unforgettable
# 0    False         False  ...     True           True
# 1    False         False  ...     True           True
# 2    False         False  ...     True           True
# 3    False         False  ...     True           True
# 4    False         False  ...     True           True
# ..     ...           ...  ...      ...            ...
# 361  False         False  ...    False          False
# 362  False         False  ...    False          False
# 363  False         False  ...    False          False
# 364  False         False  ...    False          False
# 365  False         False  ...    False          False
#
# [366 rows x 6 columns]

# %%
df.sample(5)
# Out:
#            Date  Shape of You  ...    HUMBLE.  Unforgettable
# 356  2017-12-31       7073032  ...  2787752.0      3792953.0
# 151  2017-06-09       8347951  ...  7130699.0      6435133.0
# 18   2017-01-24      14322902  ...        NaN            NaN
# 144  2017-06-01       8270321  ...  7364896.0      5738504.0
# 132  2017-05-18       9162677  ...  8431003.0      5096004.0
#
# [5 rows x 6 columns]

# %%
df.shape
# Out:
# (366, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      366 non-null    object
#  1   Shape of You              366 non-null    int64
#  2   Despacito                 359 non-null    float64
#  3   Something Just Like This  319 non-null    float64
#  4   HUMBLE.                   282 non-null    float64
#  5   Unforgettable             275 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 17.3+ KB

# %%
import matplotlib.pyplot as plt

# %%
p=pd.read_csv("spotify.csv")
s=df["Date"].head(100)
v=df['HUMBLE.'].head(100)
w=plt.figure(figsize=(36,24))
plt.bar(s[:100],v[:100])
plt.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('spotify.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series.plot()
pyplot.show()

# %%
data = pd.read_csv("spotify.csv")
data.head()
df = pd.DataFrame(data)
Date = df['Date'].head(20)
Despacito = df['Despacito'].head(20)
fig = plt.figure(figsize =(38, 24))
plt.bar(Date[0:20], Despacito[0:20])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(10)
data = pd.read_csv("spotify.csv")
data=np.random.normal(100,20,200)
fig=plt.figure(figsize=(10,7))
plt.boxplot(data)
plt.show()

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
data = pd.read_csv("spotify.csv")
data=[{2,3,4,1},{6,3,5,2},{6,3,5,4},{3,7,5,4},{2,8,1,5}]
Index= ['I1', 'I2','I3','I4','I5']
Cols = ['C1', 'C2', 'C3','C4']
df = DataFrame(data, index=Index, columns=Cols)

plt.pcolor(df)
plt.show()

# %%
import plotly.figure_factory as ff
import numpy as np
np.random.seed(1)
data = pd.read_csv("spotify.csv")
X = np.random.rand(15, 12) 
fig = ff.create_dendrogram(X)
fig.update_layout(width=800, height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
